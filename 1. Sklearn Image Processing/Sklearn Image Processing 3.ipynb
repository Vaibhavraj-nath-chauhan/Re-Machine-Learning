# %%
import os
os.chdir("..\\Sklearn Image Processing")
import matplotlib.pyplot as plt
import numpy as np
from skimage import data
            
exec(open(os.path.abspath('image_common_utils.py')).read())   #reading pre traning filed for funtions

# %% [markdown]
# ##### Color images

# %%
cat = data.chelsea()
type(cat)
print(cat.shape)
show_image(cat, None)
# Out:
# (300, 451, 3)

# %%
# set the pixel at row 51, column 51 to black
cat[59,:] = 0

# set the pixel at row 51, column 61 to green
cat[50, :] = [0, 255, 0] # [red, green, blue]
show_image(cat, None)

# %%
#Checking greeinsh shades
cat = data.chelsea()
some_threshold = cat[:, :, 0] > 160
cat[some_threshold] = [0, 255, 0] # RGB
show_image(cat, None) # More greenish

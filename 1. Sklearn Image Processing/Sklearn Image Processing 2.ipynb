# %%
import matplotlib.pyplot as plt
import numpy as np
from skimage import data

# %% [markdown]
# ##### Basic exploration by inbuilt images - Explore various Numpy features

# %%
camera = data.camera()  #reading a set image of module
print(type(camera))
print(camera.shape ,camera.size)
print(camera.min(), camera.max(), camera.mean())  #fetching minimum vaue
# Out:
# <class 'numpy.ndarray'>
# (512, 512) 262144
# 0 255 118.31400299072266

# %%
print(camera[10:20])  # Get the value of the pixel on the 10th row and 20th column
camera[3,10] = 0     # Set to black the pixel on the 3rd row and 10th column
camera[:10] = 0      #setting the 10 row to black color and we can see the result
show_image(camera)    #predefined function of the imported file above
# Out:
# [[155 154 154 ... 150 152 152]
#  [155 155 155 ... 151 152 152]
#  [155 154 153 ... 151 150 150]
#  ...
#  [158 156 155 ... 148 147 147]
#  [156 154 154 ... 149 149 149]
#  [155 154 154 ... 152 153 153]]

# %%
#Masking (indexing with masks of booleans):
mask = camera < 87 # Fetching black points and converting them to 
# Set to "white" (255) pixels where mask is True
camera[mask] = 255

show_image(camera)
